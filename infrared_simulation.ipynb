# %%
import numpy as np
from sklearn.manifold import TSNE
import torch
from transformers import BertConfig, BertModel, BertTokenizer
from transformers import BertForMaskedLM, BertTokenizerFast, pipeline
from pprint import pprint
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from umap import UMAP
# Out:
# /home/customer/anaconda3/lib/python3.11/site-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(

# %%
pip show numpy
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Name: numpy
# Version: 1.24.3
# Summary: Fundamental package for array computing in Python
# Home-page: https://www.numpy.org
# Author: Travis E. Oliphant et al.
# Author-email:
# License: BSD-3-Clause
# Location: /home/customer/anaconda3/lib/python3.11/site-packages
# Requires:
# Required-by: astropy, bert-serving-client, bokeh, Bottleneck, contourpy, daal4py, datasets, datashader, datashape, gensim, h5py, holoviews, hvplot, imagecodecs, imageio, imbalanced-learn, matplotlib, mkl-fft, mkl-random, numba, numexpr, pandas, patsy, pyarrow, pyerfa, PyWavelets, scikit-image, scikit-learn, scipy, seaborn, statsmodels, tables, tifffile, transformers, umap-learn, xarray
# Note: you may need to restart the kernel to use updated packages.

# %%
config = BertConfig.from_json_file("config.json")
model = BertForMaskedLM.from_pretrained('/home/customer/hyr/matbert-base-cased-copy-version/matbert-base-cased')
tokenizer = BertTokenizerFast.from_pretrained('/home/customer/hyr/matbert-base-cased-copy-version/matbert-base-cased', do_lower_case=False)
# unmasker = pipeline('fill-mask', model=model, tokenizer=tokenizer)

# %%
# # 提取所有词向量
# all_word_embeddings = []
# for word in tokenizer.vocab.keys():
#     if word.isalnum():  # 只选择字母数字组合的词，排除特殊标记
#         token_id = tokenizer.encode(word, add_special_tokens=False)
#         if len(token_id) == 1:  # 确保词没有分词成多个子词
#             token_id = torch.tensor(token_id).unsqueeze(0)
#             embeddings = model.bert.embeddings.word_embeddings(token_id)
#             all_word_embeddings.append(embeddings.squeeze().detach().numpy())

# all_word_embeddings = np.array(all_word_embeddings)

# %%
# from umap import UMAP
# # 使用UMAP进行降维
# reducer = UMAP()
# embeddings_umap = reducer.fit_transform(all_word_embeddings)

# %%
# # 可视化降维后的词向量
# plt.figure(figsize=(10, 8))
# plt.scatter(embeddings_umap[:, 0], embeddings_umap[:, 1], s=10)
# plt.title('UMAP Visualization of BERT Word Embeddings')
# plt.xlabel('UMAP Dimension 1')
# plt.ylabel('UMAP Dimension 2')
# plt.show()

# %%
# ----------------------------------------------------------

# %%
# 提取所有词向量
all_word_embeddings = []
all_words = []
for word in tokenizer.vocab.keys():
    if word.isalnum():  # 只选择字母数字组合的词，排除特殊标记
        token_id = tokenizer.encode(word, add_special_tokens=False)
        if len(token_id) == 1:  # 确保词没有分词成多个子词
            token_id = torch.tensor(token_id).unsqueeze(0)
            embeddings = model.bert.embeddings.word_embeddings(token_id)
            all_word_embeddings.append(embeddings.squeeze().detach().numpy())
            all_words.append(word)

all_word_embeddings = np.array(all_word_embeddings)

# %%
from umap import UMAP
# 使用UMAP进行降维
reducer = UMAP()
embeddings_umap = reducer.fit_transform(all_word_embeddings)

# %%
# # 可视化降维后的词向量
# plt.figure(figsize=(10, 8))
# for i in range(len(all_words)):
#     plt.scatter(embeddings_umap[i, 0], embeddings_umap[i, 1], color='gray', s=20)

# # 标记高亮词汇
# for word in highlighted_words:
#     if word in all_words:
#         idx = all_words.index(word)
#         plt.scatter(embeddings_umap[idx, 0], embeddings_umap[idx, 1], color='blue', s=20)
#         plt.text(embeddings_umap[idx, 0], embeddings_umap[idx, 1], word, fontsize=8, ha='left', va='bottom', color='blue')

# plt.title('UMAP Visualization of BERT Word Embeddings')
# plt.xlabel('UMAP Dimension 1')
# plt.ylabel('UMAP Dimension 2')
# plt.savefig('figure1.png')
# plt.show()

# %%
# highlighted_words = ['perovskite','mapbi3','lamno3','batio3']
# # 可视化降维后的词向量
# plt.figure(figsize=(10, 8))
# for i in range(len(all_words)):
#     plt.scatter(embeddings_umap[i, 0], embeddings_umap[i, 1], color='gray', s=20)

# # 标记高亮词汇
# for word in highlighted_words:
#     if word in all_words:
#         idx = all_words.index(word)
#         plt.scatter(embeddings_umap[idx, 0], embeddings_umap[idx, 1], color='blue', s=20)
#         plt.text(embeddings_umap[idx, 0], embeddings_umap[idx, 1], word, fontsize=8, ha='left', va='bottom', color='blue')

# plt.title('UMAP Visualization of BERT Word Embeddings')
# plt.xlabel('UMAP Dimension 1')
# plt.ylabel('UMAP Dimension 2')
# plt.savefig('figure2.png')
# plt.show()

# %%
from sklearn.metrics.pairwise import cosine_similarity
# 计算所有词向量与"perovskite"的余弦相似度
word5_token = tokenizer.encode("emissivity", add_special_tokens=False)
word5_embedding = model.bert.embeddings.word_embeddings(torch.tensor(word5_token)).squeeze().detach().numpy()
cos_similarities1 = cosine_similarity(all_word_embeddings, [word5_embedding])

# %%
# 可视化降维后的词向量，并根据余弦相似度调整颜色深浅
plt.figure(figsize=(10, 8))
cmap = plt.cm.BuPu
scatter=plt.scatter(embeddings_umap[:, 0], embeddings_umap[:, 1], c=cos_similarities1.squeeze(), cmap=cmap, s=20)

# 标记高亮词汇
highlighted_words = ['Al2O3','Y2O3','AlN','YAG']
for word in highlighted_words:
    if word in all_words:
        idx = all_words.index(word)
        plt.scatter(embeddings_umap[idx, 0], embeddings_umap[idx, 1], color='red', marker='o', s=20)
        # plt.text(embeddings_umap[idx, 0], embeddings_umap[idx, 1], word, fontsize=8, ha='left', va='bottom', color='red')

highlighted_words = ['Al2O3','Y2O3','AlN','YAG']
for word in highlighted_words:
    if word in all_words:
        idx = all_words.index(word)
        plt.scatter(embeddings_umap[idx, 0], embeddings_umap[idx, 1], color='red', marker='o', s=20)
        # plt.text(embeddings_umap[idx, 0], embeddings_umap[idx, 1], word, fontsize=8, ha='left', va='bottom', color='red')
       
    

plt.title('UMAP Visualization of BERT Word Embeddings')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')

# 添加颜色条
cbar = plt.colorbar(scatter)
cbar.set_label('Cosine Similarity')

# 设置颜色条的范围，使其只显示蓝色部分
cbar.set_ticks(np.linspace(0, 1, 6))

# plt.axis([-50, 50, -60, 60])


plt.savefig("figure3_word_embeddings_visualization.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# 'Al2O3','Y2O3','AlN','YAG
# Nb2O5   Mn3O4  Co3O4


word1_index = all_words.index("Al2O3")
word2_index = all_words.index("Y2O3")
word3_index = all_words.index("AlN")
word4_index = all_words.index("YAG")
# word5_index = all_words.index("Nb2O5")
# word6_index = all_words.index("Mn3O4")
# word7_index = all_words.index("Co3O4")


cmap = plt.cm.BuPu
plt.figure(figsize=(10, 8))

# 根据余弦相似性调整颜色深浅并绘制散点图

colors = cmap(cos_similarities1.ravel())
# scatter = plt.scatter(embeddings_umap[:, 0], embeddings_umap[:, 1], c=colors, alpha=0.5)
scatter=plt.scatter(embeddings_umap[:, 0], embeddings_umap[:, 1], c=cos_similarities1.squeeze(), cmap=cmap, s=20)

plt.scatter(embeddings_umap[word1_index, 0], embeddings_umap[word1_index, 1], c='red', marker='*', s=50, label='Al2O3')
plt.scatter(embeddings_umap[word2_index, 0], embeddings_umap[word2_index, 1], c='red', marker='*', s=50, label='Y2O3')
plt.scatter(embeddings_umap[word3_index, 0], embeddings_umap[word3_index, 1], c='red', marker='*', s=50, label='AlN')
plt.scatter(embeddings_umap[word4_index, 0], embeddings_umap[word4_index, 1], c='red', marker='*', s=50, label='YAG')
# plt.scatter(embeddings_umap[word5_index, 0], embeddings_umap[word5_index, 1], c='red', marker='*', s=50, label='Nb2O5')
# plt.scatter(embeddings_umap[word6_index, 0], embeddings_umap[word6_index, 1], c='red', marker='*', s=50, label='Mn3O4')
# plt.scatter(embeddings_umap[word7_index, 0], embeddings_umap[word7_index, 1], c='red', marker='*', s=50, label='Co3O4')


plt.title('UMAP Visualization of BERT Word Embeddings')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')

# 添加颜色条
cbar = plt.colorbar(scatter, ticks=np.linspace(colors.min(), colors.max(), 6))
cbar.set_label('Cosine Similarity')

plt.legend()
plt.savefig("figure3_word_embeddings_visualization.png")
plt.show()

# %%
# 可视化降维后的词向量，并根据余弦相似度调整颜色深浅
plt.figure(figsize=(10, 8))

# plt.cm.Blues: 蓝色调色板
# plt.cm.Greens: 绿色调色板
# plt.cm.Reds: 红色调色板
# plt.cm.Oranges: 橙色调色板
# plt.cm.Purples: 紫色调色板
# plt.cm.Greys: 灰色调色板
# plt.cm.YlOrBr: 黄橙棕色调色板
# plt.cm.YlOrRd: 黄橙红色调色板
# marker='o',marker='s'marker='^'、marker='v'、marker='<'、marker='>' marker='+'marker='x'
cmap = plt.cm.BuPu
scatter=plt.scatter(embeddings_umap[:, 0], embeddings_umap[:, 1], c=cos_similarities1.squeeze(), cmap=cmap, s=20)

# 标记高亮词汇
highlighted_words = ["MAPbI3"]
for word in highlighted_words:
    if word in all_words:
        idx = all_words.index(word)
        plt.scatter(embeddings_umap[idx, 0], embeddings_umap[idx, 1], color='red', marker='*',s=50)
        plt.text(embeddings_umap[idx, 0], embeddings_umap[idx, 1], word, fontsize=8, ha='left', va='bottom', color='red')

plt.title('UMAP Visualization of BERT Word Embeddings')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')

# 添加颜色条
cbar = plt.colorbar(scatter)
cbar.set_label('Cosine Similarity')

# 设置颜色条的范围，使其只显示蓝色部分
cbar.set_ticks(np.linspace(0, 1, 6))

# plt.axis([-50, 50, -60, 60])

plt.savefig("figure4_word_embeddings_visualization.png")
plt.show()

# %%
 # 目标词汇1
word3_token = tokenizer.encode("perovskite", add_special_tokens=False)
word3_embedding = model.bert.embeddings.word_embeddings(torch.tensor(word3_token)).squeeze().detach().numpy()
cos_word3 = cosine_similarity(all_word_embeddings, [word3_embedding])
 # 目标词汇2
word4_token = tokenizer.encode("stable", add_special_tokens=False)
word4_embedding = model.bert.embeddings.word_embeddings(torch.tensor(word4_token)).squeeze().detach().numpy()
cos_word4 = cosine_similarity(all_word_embeddings, [word4_embedding])

# %%
plt.figure(figsize=(10, 8))
# 先绘制灰色的点
gray_indices = [i for i in range(len(all_words)) if cos_word3[i] <= 0.4 and cos_word4[i] <= 0.4]
gray_embeddings_umap = embeddings_umap[gray_indices]
plt.scatter(gray_embeddings_umap[:, 0], gray_embeddings_umap[:, 1], color='gray', s=20)

# 再绘制高亮的点
highlighted_indices = [i for i in range(len(all_words)) if i not in gray_indices]
highlighted_embeddings_umap = embeddings_umap[highlighted_indices]
highlighted_colors = ['blue' if cos_word3[i] > 0.4 else 'green' for i in highlighted_indices]
plt.scatter(highlighted_embeddings_umap[:, 0], highlighted_embeddings_umap[:, 1], c=highlighted_colors, s=20)

# # 标记高亮词汇
# highlighted_words = ["perovskite", "lamno3", "stable"]
# highlighted_colors = ['blue', 'red', 'green']
# for word, color in zip(highlighted_words, highlighted_colors):
#     if word in all_words:
#         idx = all_words.index(word)
#         plt.scatter(embeddings_umap[idx, 0], embeddings_umap[idx, 1], color=color, s=20)
#         plt.text(embeddings_umap[idx, 0], embeddings_umap[idx, 1], word, fontsize=8, ha='left', va='bottom', color=color)

plt.title('UMAP Visualization of BERT Word Embeddings')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.savefig("figure5_word_embeddings_visualization.png")
plt.show()

# %%
plt.figure(figsize=(10, 8))

# 先绘制灰色的点
plt.scatter(embeddings_umap[:, 0], embeddings_umap[:, 1], color='gray', s=20)

# 高亮的词语及其对应的位置
highlighted_words_blue = ['Al2O3','Y2O3','AlN','YAG']  #典型钙钛矿
highlighted_words_green = ['phonon']  #典型HTL材料
highlighted_words_yellow = ['emissivity']  #锂电池正极材料
''
for word in highlighted_words_blue:
    if word in all_words:
        idx = all_words.index(word)
        plt.scatter(embeddings_umap[idx, 0], embeddings_umap[idx, 1], color='blue', s=20)
        plt.text(embeddings_umap[idx, 0], embeddings_umap[idx, 1], word, fontsize=8, ha='left', va='bottom', color='blue')
        
for word in highlighted_words_green:
    if word in all_words:
        idx = all_words.index(word)
        plt.scatter(embeddings_umap[idx, 0], embeddings_umap[idx, 1], color='green', s=20)
        # plt.text(embeddings_umap[idx, 0], embeddings_umap[idx, 1], word, fontsize=8, ha='left', va='bottom', color='green')
        
for word in highlighted_words_yellow:
    if word in all_words:
        idx = all_words.index(word)
        plt.scatter(embeddings_umap[idx, 0], embeddings_umap[idx, 1], color='yellow', s=20)
        # plt.text(embeddings_umap[idx, 0], embeddings_umap[idx, 1], word, fontsize=8, ha='left', va='bottom', color='yellow')

plt.title('UMAP Visualization of BERT Word Embeddings')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.savefig("word_embeddings_visualization.png")
plt.show()

# %%
# 定义要比较的词
target_word1 = "emissivity"
# 计算目标词与所有其他词的余弦相似度
target_token_id = tokenizer.encode(target_word1, add_special_tokens=False)
target_embedding = model.bert.embeddings.word_embeddings(torch.tensor(target_token_id)).squeeze().detach().numpy()
cos_similarities2 = cosine_similarity(all_word_embeddings, [target_embedding])
# 对相似度进行排序并获取排序后的索引
sorted_indices = np.argsort(cos_similarities2.flatten())[::-1]

# 打印排名和相似度
print("cosine similarity for '{}':".format(target_word1))
for rank, idx in enumerate(sorted_indices):
    word = all_words[idx]
    similarity = cos_similarities2[idx][0]
    print("{}: {} (Cosine Similarity: {:.4f})".format(rank + 1, word, similarity))
# Out:
# cosine similarity for 'emissivity':
# 1: emissivity (Cosine Similarity: 1.0000)
# 2: emis (Cosine Similarity: 0.6533)
# 3: emittance (Cosine Similarity: 0.6118)
# 4: absorptivity (Cosine Similarity: 0.6055)
# 5: reflectivity (Cosine Similarity: 0.5598)
# 6: emissive (Cosine Similarity: 0.5445)
# 7: NDVI (Cosine Similarity: 0.5411)
# 8: albedo (Cosine Similarity: 0.5388)
# 9: emits (Cosine Similarity: 0.5283)
# 10: thermophysical (Cosine Similarity: 0.5274)
# 11: radiance (Cosine Similarity: 0.5255)
# 12: permittivity (Cosine Similarity: 0.5204)
# 13: Emission (Cosine Similarity: 0.5169)
# 14: photoactivity (Cosine Similarity: 0.5054)
# 15: AOD (Cosine Similarity: 0.5021)
# 16: reflectance (Cosine Similarity: 0.5005)
# 17: IPCE (Cosine Similarity: 0.5000)
# 18: thermocouples (Cosine Similarity: 0.4997)
# 19: Photoluminescence (Cosine Similarity: 0.4997)
# 20: spectrally (Cosine Similarity: 0.4969)
# 21: insolation (Cosine Similarity: 0.4957)
# 22: EQE (Cosine Similarity: 0.4953)
# 23: thermograms (Cosine Similarity: 0.4948)
# 24: electroluminescence (Cosine Similarity: 0.4942)
# 25: varepsilon (Cosine Similarity: 0.4930)
# 26: porosities (Cosine Similarity: 0.4913)
# 27: eclog (Cosine Similarity: 0.4885)
# 28: photoconductivity (Cosine Similarity: 0.4878)
# 29: responsivity (Cosine Similarity: 0.4876)
# 30: HER2 (Cosine Similarity: 0.4863)
# 31: εr (Cosine Similarity: 0.4851)
# 32: GWP (Cosine Similarity: 0.4842)
# 33: ARPES (Cosine Similarity: 0.4808)
# 34: volati (Cosine Similarity: 0.4805)
# 35: entropies (Cosine Similarity: 0.4799)
# 36: luminosity (Cosine Similarity: 0.4795)
# 37: metamorphism (Cosine Similarity: 0.4793)
# 38: pyroelectric (Cosine Similarity: 0.4775)
# 39: Impedance (Cosine Similarity: 0.4762)
# 40: Espec (Cosine Similarity: 0.4758)
# 41: emit (Cosine Similarity: 0.4756)
# 42: Prandtl (Cosine Similarity: 0.4753)
# 43: thermopower (Cosine Similarity: 0.4730)
# 44: emotion (Cosine Similarity: 0.4729)
# 45: ellipsometry (Cosine Similarity: 0.4727)
# 46: MODIS (Cosine Similarity: 0.4716)
# 47: ν3 (Cosine Similarity: 0.4714)
# 48: congl (Cosine Similarity: 0.4711)
# 49: conductivities (Cosine Similarity: 0.4706)
# 50: phosphors (Cosine Similarity: 0.4704)
# 51: QY (Cosine Similarity: 0.4704)
# 52: diffusivities (Cosine Similarity: 0.4704)
# 53: yttria (Cosine Similarity: 0.4701)
# 54: evapotranspiration (Cosine Similarity: 0.4696)
# 55: combustor (Cosine Similarity: 0.4688)
# 56: nighttime (Cosine Similarity: 0.4685)
# 57: painted (Cosine Similarity: 0.4684)
# 58: εs (Cosine Similarity: 0.4676)
# 59: heaters (Cosine Similarity: 0.4675)
# 60: metamaterials (Cosine Similarity: 0.4675)
# 61: depar (Cosine Similarity: 0.4667)
# 62: tortuosity (Cosine Similarity: 0.4667)
# 63: alkynes (Cosine Similarity: 0.4664)
# 64: asth (Cosine Similarity: 0.4660)
# 65: solubilities (Cosine Similarity: 0.4658)
# 66: unburn (Cosine Similarity: 0.4658)
# 67: exhum (Cosine Similarity: 0.4654)
# 68: Y2O3 (Cosine Similarity: 0.4652)
# 69: Annealing (Cosine Similarity: 0.4646)
# 70: Heating (Cosine Similarity: 0.4644)
# 71: Infrared (Cosine Similarity: 0.4641)
# 72: electrol (Cosine Similarity: 0.4641)
# 73: LDOS (Cosine Similarity: 0.4640)
# 74: photovoltage (Cosine Similarity: 0.4640)
# 75: calorific (Cosine Similarity: 0.4638)
# 76: teph (Cosine Similarity: 0.4636)
# 77: Climate (Cosine Similarity: 0.4631)
# 78: Porous (Cosine Similarity: 0.4631)
# 79: Education (Cosine Similarity: 0.4628)
# 80: flammability (Cosine Similarity: 0.4628)
# 81: photodetectors (Cosine Similarity: 0.4623)
# 82: UCNPs (Cosine Similarity: 0.4620)
# 83: zirc (Cosine Similarity: 0.4617)
# 84: Electricity (Cosine Similarity: 0.4616)
# 85: radiated (Cosine Similarity: 0.4614)
# 86: contrib (Cosine Similarity: 0.4613)
# 87: Images (Cosine Similarity: 0.4611)
# 88: relaxor (Cosine Similarity: 0.4608)
# 89: unexp (Cosine Similarity: 0.4608)
# 90: LAI (Cosine Similarity: 0.4605)
# 91: anharmonicity (Cosine Similarity: 0.4602)
# 92: irradiance (Cosine Similarity: 0.4601)
# 93: luminance (Cosine Similarity: 0.4599)
# 94: Atmospheric (Cosine Similarity: 0.4590)
# 95: semiconduc (Cosine Similarity: 0.4590)
# 96: longitude (Cosine Similarity: 0.4589)
# 97: thermocouple (Cosine Similarity: 0.4588)
# 98: Ē (Cosine Similarity: 0.4588)
# 99: electrochromic (Cosine Similarity: 0.4585)
# 100: coverages (Cosine Similarity: 0.4583)
# 101: EGFR (Cosine Similarity: 0.4582)
# 102: austen (Cosine Similarity: 0.4581)
# 103: Arrhen (Cosine Similarity: 0.4581)
# 104: Infr (Cosine Similarity: 0.4577)
# 105: overheating (Cosine Similarity: 0.4577)
# 106: Radiation (Cosine Similarity: 0.4577)
# 107: Δε (Cosine Similarity: 0.4576)
# 108: spectrophotometrically (Cosine Similarity: 0.4576)
# 109: eccentricity (Cosine Similarity: 0.4575)
# 110: ecos (Cosine Similarity: 0.4571)
# 111: abdom (Cosine Similarity: 0.4570)
# 112: transpar (Cosine Similarity: 0.4569)
# 113: furn (Cosine Similarity: 0.4568)
# 114: ellipso (Cosine Similarity: 0.4564)
# 115: photoble (Cosine Similarity: 0.4562)
# 116: imperme (Cosine Similarity: 0.4562)
# 117: thermop (Cosine Similarity: 0.4557)
# 118: Thermogravimetric (Cosine Similarity: 0.4556)
# 119: latitudes (Cosine Similarity: 0.4556)
# 120: thermometer (Cosine Similarity: 0.4556)
# 121: interferometry (Cosine Similarity: 0.4555)
# 122: afternoon (Cosine Similarity: 0.4555)
# 123: Temperature (Cosine Similarity: 0.4547)
# 124: photoresponse (Cosine Similarity: 0.4546)
# 125: optoelectronic (Cosine Similarity: 0.4546)
# 126: Seebeck (Cosine Similarity: 0.4544)
# 127: nonradiative (Cosine Similarity: 0.4543)
# 128: ε2 (Cosine Similarity: 0.4543)
# 129: PCMs (Cosine Similarity: 0.4540)
# 130: fluorophores (Cosine Similarity: 0.4537)
# 131: interferometer (Cosine Similarity: 0.4532)
# 132: colder (Cosine Similarity: 0.4528)
# 133: renormal (Cosine Similarity: 0.4528)
# 134: phthalocyanines (Cosine Similarity: 0.4526)
# 135: Evalu (Cosine Similarity: 0.4517)
# 136: atmosp (Cosine Similarity: 0.4517)
# 137: superconduc (Cosine Similarity: 0.4516)
# 138: Oligocene (Cosine Similarity: 0.4508)
# 139: Yvon (Cosine Similarity: 0.4506)
# 140: Mountains (Cosine Similarity: 0.4505)
# 141: basicity (Cosine Similarity: 0.4505)
# 142: anodized (Cosine Similarity: 0.4505)
# 143: NMe2 (Cosine Similarity: 0.4504)
# 144: feld (Cosine Similarity: 0.4504)
# 145: transmis (Cosine Similarity: 0.4501)
# 146: 870 (Cosine Similarity: 0.4499)
# 147: accuracies (Cosine Similarity: 0.4498)
# 148: HAZ (Cosine Similarity: 0.4498)
# 149: reflectors (Cosine Similarity: 0.4498)
# 150: Spectrometer (Cosine Similarity: 0.4497)
# 151: Tb3 (Cosine Similarity: 0.4497)
# 152: dehydrox (Cosine Similarity: 0.4494)
# 153: Absorption (Cosine Similarity: 0.4494)
# 154: LCST (Cosine Similarity: 0.4494)
# 155: toluenesulf (Cosine Similarity: 0.4492)
# 156: Thermodynamic (Cosine Similarity: 0.4492)
# 157: Siber (Cosine Similarity: 0.4490)
# 158: vibrationally (Cosine Similarity: 0.4489)
# 159: Nusselt (Cosine Similarity: 0.4488)
# 160: spanwise (Cosine Similarity: 0.4487)
# 161: aminobenz (Cosine Similarity: 0.4487)
# 162: pO2 (Cosine Similarity: 0.4487)
# 163: bluesh (Cosine Similarity: 0.4485)
# 164: photoemission (Cosine Similarity: 0.4484)
# 165: ribb (Cosine Similarity: 0.4484)
# 166: altitudes (Cosine Similarity: 0.4483)
# 167: XMCD (Cosine Similarity: 0.4481)
# 168: Δλ (Cosine Similarity: 0.4481)
# 169: theore (Cosine Similarity: 0.4480)
# 170: photocatalysis (Cosine Similarity: 0.4480)
# 171: Tef (Cosine Similarity: 0.4480)
# 172: permeabilities (Cosine Similarity: 0.4479)
# 173: photostability (Cosine Similarity: 0.4477)
# 174: senes (Cosine Similarity: 0.4477)
# 175: optoelectronics (Cosine Similarity: 0.4476)
# 176: landsc (Cosine Similarity: 0.4476)
# 177: pyroxene (Cosine Similarity: 0.4473)
# 178: crucibles (Cosine Similarity: 0.4472)
# 179: Probes (Cosine Similarity: 0.4470)
# 180: Hamamatsu (Cosine Similarity: 0.4464)
# 181: discrep (Cosine Similarity: 0.4463)
# 182: weathered (Cosine Similarity: 0.4462)
# 183: obj (Cosine Similarity: 0.4462)
# 184: virulence (Cosine Similarity: 0.4461)
# 185: malignant (Cosine Similarity: 0.4461)
# 186: Aliquots (Cosine Similarity: 0.4461)
# 187: Cool (Cosine Similarity: 0.4459)
# 188: Tm3 (Cosine Similarity: 0.4458)
# 189: Nikon (Cosine Similarity: 0.4457)
# 190: malign (Cosine Similarity: 0.4457)
# 191: explos (Cosine Similarity: 0.4457)
# 192: photosensitiz (Cosine Similarity: 0.4457)
# 193: spectrophot (Cosine Similarity: 0.4454)
# 194: Concentrations (Cosine Similarity: 0.4453)
# 195: pyrox (Cosine Similarity: 0.4451)
# 196: birefring (Cosine Similarity: 0.4450)
# 197: photoanodes (Cosine Similarity: 0.4450)
# 198: abundances (Cosine Similarity: 0.4450)
# 199: inconsist (Cosine Similarity: 0.4450)
# 200: acetylacet (Cosine Similarity: 0.4450)
# 201: dielectrics (Cosine Similarity: 0.4448)
# 202: fluences (Cosine Similarity: 0.4447)
# 203: inexp (Cosine Similarity: 0.4447)
# 204: plagi (Cosine Similarity: 0.4447)
# 205: isothi (Cosine Similarity: 0.4444)
# 206: exotherm (Cosine Similarity: 0.4444)
# 207: gneiss (Cosine Similarity: 0.4442)
# 208: evapor (Cosine Similarity: 0.4441)
# 209: abund (Cosine Similarity: 0.4441)
# 210: phosphorescent (Cosine Similarity: 0.4439)
# 211: Exposure (Cosine Similarity: 0.4439)
# 212: Melting (Cosine Similarity: 0.4439)
# 213: unconform (Cosine Similarity: 0.4439)
# 214: unequ (Cosine Similarity: 0.4438)
# 215: œ (Cosine Similarity: 0.4438)
# 216: turbul (Cosine Similarity: 0.4437)
# 217: senescence (Cosine Similarity: 0.4433)
# 218: superhydroph (Cosine Similarity: 0.4431)
# 219: acqu (Cosine Similarity: 0.4431)
# 220: climates (Cosine Similarity: 0.4431)
# 221: tellur (Cosine Similarity: 0.4430)
# 222: chemil (Cosine Similarity: 0.4430)
# 223: fibronectin (Cosine Similarity: 0.4430)
# 224: adhe (Cosine Similarity: 0.4429)
# 225: aure (Cosine Similarity: 0.4429)
# 226: infr (Cosine Similarity: 0.4428)
# 227: redshift (Cosine Similarity: 0.4428)
# 228: intu (Cosine Similarity: 0.4428)
# 229: biodistribution (Cosine Similarity: 0.4427)
# 230: DRIFT (Cosine Similarity: 0.4427)
# 231: Mettler (Cosine Similarity: 0.4427)
# 480: roug (Cosine Similarity: 0.4293)
# 481: intellig (Cosine Similarity: 0.4292)
# 482: ℛ (Cosine Similarity: 0.4292)
# 483: photoelectrochemical (Cosine Similarity: 0.4291)
# 484: undercooling (Cosine Similarity: 0.4291)
# 485: eleg (Cosine Similarity: 0.4291)
# 486: nitriles (Cosine Similarity: 0.4290)
# 487: ellipticity (Cosine Similarity: 0.4290)
# 488: Δν (Cosine Similarity: 0.4290)
# 489: Ф (Cosine Similarity: 0.4289)
# 490: interband (Cosine Similarity: 0.4289)
# 491: 287 (Cosine Similarity: 0.4287)
# 492: sublimation (Cosine Similarity: 0.4287)
# 493: burnup (Cosine Similarity: 0.4286)
# 494: occup (Cosine Similarity: 0.4284)
# 495: lineshape (Cosine Similarity: 0.4284)
# 496: epitope (Cosine Similarity: 0.4284)
# 497: OD600 (Cosine Similarity: 0.4284)
# 498: dun (Cosine Similarity: 0.4283)
# 499: dunes (Cosine Similarity: 0.4283)
# 500: C5Me (Cosine Similarity: 0.4282)
# 501: elabor (Cosine Similarity: 0.4282)
# 502: photoluminescence (Cosine Similarity: 0.4282)
# 503: Nujol (Cosine Similarity: 0.4281)
# 504: gasifier (Cosine Similarity: 0.4281)
# 505: nort (Cosine Similarity: 0.4281)
# 506: Phot (Cosine Similarity: 0.4281)
# 507: equiaxed (Cosine Similarity: 0.4280)
# 508: tempering (Cosine Similarity: 0.4280)
# 509: respon (Cosine Similarity: 0.4280)
# 510: tocop (Cosine Similarity: 0.4279)
# 511: photodetector (Cosine Similarity: 0.4279)
# 512: convinc (Cosine Similarity: 0.4278)
# 513: roofs (Cosine Similarity: 0.4278)
# 514: iNOS (Cosine Similarity: 0.4278)
# 515: Eu2 (Cosine Similarity: 0.4278)
# 516: enthalpies (Cosine Similarity: 0.4278)
# 517: Dimethyl (Cosine Similarity: 0.4277)
# 518: haze (Cosine Similarity: 0.4277)
# 519: embritt (Cosine Similarity: 0.4275)
# 520: temperat (Cosine Similarity: 0.4274)
# 521: Zirc (Cosine Similarity: 0.4274)
# 522: colours (Cosine Similarity: 0.4274)
# 523: elast (Cosine Similarity: 0.4273)
# 524: diamin (Cosine Similarity: 0.4273)
# 525: Avrami (Cosine Similarity: 0.4273)
# 526: negl (Cosine Similarity: 0.4272)
# 527: concomit (Cosine Similarity: 0.4271)
# 528: Particip (Cosine Similarity: 0.4271)
# 529: ξ2 (Cosine Similarity: 0.4271)
# 530: reh (Cosine Similarity: 0.4271)
# 531: electropl (Cosine Similarity: 0.4270)
# 532: Version (Cosine Similarity: 0.4270)
# 533: nmol (Cosine Similarity: 0.4270)
# 534: vap (Cosine Similarity: 0.4269)
# 535: reefs (Cosine Similarity: 0.4269)
# 536: mTorr (Cosine Similarity: 0.4268)
# 537: tetraphenyl (Cosine Similarity: 0.4268)
# 538: indistingu (Cosine Similarity: 0.4268)
# 539: photocatalysts (Cosine Similarity: 0.4267)
# 540: Tibet (Cosine Similarity: 0.4267)
# 541: metamaterial (Cosine Similarity: 0.4267)
# 668: sinh (Cosine Similarity: 0.4229)
# 669: alkynyl (Cosine Similarity: 0.4229)
# 670: Optical (Cosine Similarity: 0.4228)
# 671: undes (Cosine Similarity: 0.4228)
# 672: Darcy (Cosine Similarity: 0.4228)
# 673: isentropic (Cosine Similarity: 0.4228)
# 674: Russia (Cosine Similarity: 0.4228)
# 675: HZSM (Cosine Similarity: 0.4227)
# 676: chl (Cosine Similarity: 0.4226)
# 677: ilmenite (Cosine Similarity: 0.4226)
# 678: aspartic (Cosine Similarity: 0.4226)
# 679: RMSD (Cosine Similarity: 0.4226)
# 680: α3 (Cosine Similarity: 0.4226)
# 681: biogeochemical (Cosine Similarity: 0.4226)
# 682: redund (Cosine Similarity: 0.4225)
# 683: Refl (Cosine Similarity: 0.4225)
# 684: Ũ (Cosine Similarity: 0.4225)
# 685: FSW (Cosine Similarity: 0.4225)
# 686: emotional (Cosine Similarity: 0.4225)
# 687: destr (Cosine Similarity: 0.4225)
# 688: hyg (Cosine Similarity: 0.4225)
# 689: absorbs (Cosine Similarity: 0.4224)
# 690: downregulation (Cosine Similarity: 0.4224)
# 691: alkyn (Cosine Similarity: 0.4223)
# 692: radioactivity (Cosine Similarity: 0.4223)
# 693: benzoic (Cosine Similarity: 0.4222)
# 694: intermitt (Cosine Similarity: 0.4222)
# 695: subj (Cosine Similarity: 0.4222)
# 696: Safety (Cosine Similarity: 0.4222)
# 697: unexpl (Cosine Similarity: 0.4222)
# 698: Kingdom (Cosine Similarity: 0.4222)
# 699: OLED (Cosine Similarity: 0.4222)
# 700: lubricants (Cosine Similarity: 0.4221)
# 701: 808 (Cosine Similarity: 0.4221)
# 702: divertor (Cosine Similarity: 0.4220)
# 703: photoanode (Cosine Similarity: 0.4220)
# 704: formability (Cosine Similarity: 0.4220)
# 705: O1s (Cosine Similarity: 0.4220)
# 706: iden (Cosine Similarity: 0.4219)
# 707: EPMA (Cosine Similarity: 0.4218)
# 708: laun (Cosine Similarity: 0.4217)
# 709: CD3CN (Cosine Similarity: 0.4217)
# 710: attitude (Cosine Similarity: 0.4217)
# 711: 326 (Cosine Similarity: 0.4216)
# 712: i2 (Cosine Similarity: 0.4216)
# 713: statis (Cosine Similarity: 0.4216)
# 714: Jobin (Cosine Similarity: 0.4215)
# 715: atherosclerosis (Cosine Similarity: 0.4215)
# 716: InGaAs (Cosine Similarity: 0.4215)
# 717: accelerometer (Cosine Similarity: 0.4215)
# 718: Ryd (Cosine Similarity: 0.4214)
# 719: trifluorometh (Cosine Similarity: 0.4214)
# 720: ero (Cosine Similarity: 0.4213)
# 721: imagery (Cosine Similarity: 0.4213)
# 722: Olymp (Cosine Similarity: 0.4213)
# 723: geomorph (Cosine Similarity: 0.4213)
# 724: linewidth (Cosine Similarity: 0.4212)
# 725: wavenumber (Cosine Similarity: 0.4212)
# 726: paints (Cosine Similarity: 0.4212)
# 727: enclosure (Cosine Similarity: 0.4212)
# 728: pyrim (Cosine Similarity: 0.4212)
# 729: unres (Cosine Similarity: 0.4212)
# 730: bathym (Cosine Similarity: 0.4212)
# 731: CaSO4 (Cosine Similarity: 0.4211)
# 732: xer (Cosine Similarity: 0.4211)
# 733: anomal (Cosine Similarity: 0.4211)
# 734: 378 (Cosine Similarity: 0.4211)
# 735: photoexc (Cosine Similarity: 0.4210)
# 736: pVTZ (Cosine Similarity: 0.4209)
# 737: Bi2S3 (Cosine Similarity: 0.4209)
# 738: Ω2 (Cosine Similarity: 0.4209)
# 739: Partic (Cosine Similarity: 0.4209)
# 740: linole (Cosine Similarity: 0.4209)
# 741: pock (Cosine Similarity: 0.4209)
# 742: Ü (Cosine Similarity: 0.4209)
# 743: magnetostriction (Cosine Similarity: 0.4208)
# 744: eigenst (Cosine Similarity: 0.4207)
# 745: machined (Cosine Similarity: 0.4207)
# 746: ontology (Cosine Similarity: 0.4207)
# 747: δ13 (Cosine Similarity: 0.4206)
# 748: forec (Cosine Similarity: 0.4205)
# 749: Ż (Cosine Similarity: 0.4205)
# 750: dimethoxy (Cosine Similarity: 0.4205)
# 751: Eocene (Cosine Similarity: 0.4205)
# 752: tiles (Cosine Similarity: 0.4204)
# 753: upconversion (Cosine Similarity: 0.4204)
# 754: Agric (Cosine Similarity: 0.4204)
# 755: Hydrox (Cosine Similarity: 0.4204)
# 756: Sah (Cosine Similarity: 0.4204)
# 757: mism (Cosine Similarity: 0.4204)
# 758: regul (Cosine Similarity: 0.4203)
# 759: shading (Cosine Similarity: 0.4203)
# 760: chemisorbed (Cosine Similarity: 0.4203)
# 761: exfol (Cosine Similarity: 0.4202)
# 762: 2ν (Cosine Similarity: 0.4201)
# 763: volcan (Cosine Similarity: 0.4201)
# 764: σn (Cosine Similarity: 0.4201)
# 765: asperity (Cosine Similarity: 0.4201)
# 766: tungst (Cosine Similarity: 0.4200)
# 767: oxyhydrox (Cosine Similarity: 0.4200)
# 768: Ş (Cosine Similarity: 0.4200)
# 769: Sb2 (Cosine Similarity: 0.4199)
# 770: σz (Cosine Similarity: 0.4199)
# 771: Presum (Cosine Similarity: 0.4199)
# 772: spectros (Cosine Similarity: 0.4199)
# 773: 306 (Cosine Similarity: 0.4199)
# 774: Quantification (Cosine Similarity: 0.4199)
# 775: 647 (Cosine Similarity: 0.4198)
# 776: Bi2WO6 (Cosine Similarity: 0.4198)
# 777: influ (Cosine Similarity: 0.4198)
# 778: 1650 (Cosine Similarity: 0.4198)
# 779: defin (Cosine Similarity: 0.4197)
# 780: Weyl (Cosine Similarity: 0.4196)
# 781: pharmacokinetics (Cosine Similarity: 0.4196)
# 782: embank (Cosine Similarity: 0.4195)
# 783: occupants (Cosine Similarity: 0.4195)
# 784: Ez (Cosine Similarity: 0.4194)
# 785: fluoresc (Cosine Similarity: 0.4194)
# 786: 531 (Cosine Similarity: 0.4194)
# 787: ƒ (Cosine Similarity: 0.4194)
# 788: antioxid (Cosine Similarity: 0.4193)
# 789: Zeiss (Cosine Similarity: 0.4193)
# 790: Abcam (Cosine Similarity: 0.4192)
# 791: ς (Cosine Similarity: 0.4192)
# 792: isent (Cosine Similarity: 0.4191)
# 793: Horiba (Cosine Similarity: 0.4191)
# 794: clothing (Cosine Similarity: 0.4191)
# 795: photobleaching (Cosine Similarity: 0.4191)
# 796: Europ (Cosine Similarity: 0.4191)
# 797: ejecta (Cosine Similarity: 0.4191)
# 798: stearic (Cosine Similarity: 0.4191)
# 799: Austr (Cosine Similarity: 0.4191)
# 800: TFTs (Cosine Similarity: 0.4190)
# 801: ZnPc (Cosine Similarity: 0.4190)
# 802: retrof (Cosine Similarity: 0.4190)
# 803: aerogels (Cosine Similarity: 0.4190)
# 804: metastasis (Cosine Similarity: 0.4189)
# 805: AlGaAs (Cosine Similarity: 0.4189)
# 806: Imaging (Cosine Similarity: 0.4189)
# 807: unpub (Cosine Similarity: 0.4189)
# 808: radion (Cosine Similarity: 0.4189)
# 809: sial (Cosine Similarity: 0.4189)
# 810: Spectros (Cosine Similarity: 0.4189)
# 811: luminescent (Cosine Similarity: 0.4189)
# 812: Δθ (Cosine Similarity: 0.4188)
# 813: coron (Cosine Similarity: 0.4188)
# 814: Composition (Cosine Similarity: 0.4188)
# 815: MCNP (Cosine Similarity: 0.4188)
# 816: 327 (Cosine Similarity: 0.4188)
# 817: Malay (Cosine Similarity: 0.4188)
# 818: NADP (Cosine Similarity: 0.4188)
# 819: ℝ (Cosine Similarity: 0.4187)
# 820: pati (Cosine Similarity: 0.4187)
# 821: C2H6 (Cosine Similarity: 0.4187)
# 822: chondrites (Cosine Similarity: 0.4187)
# 823: Methane (Cosine Similarity: 0.4187)
# 824: introduc (Cosine Similarity: 0.4187)
# 825: 286 (Cosine Similarity: 0.4187)
# 826: metallographic (Cosine Similarity: 0.4187)
# 827: electroless (Cosine Similarity: 0.4186)
# 828: highl (Cosine Similarity: 0.4186)
# 829: Degussa (Cosine Similarity: 0.4186)
# 830: progn (Cosine Similarity: 0.4185)
# 831: deaths (Cosine Similarity: 0.4185)
# 832: ч (Cosine Similarity: 0.4185)
# 833: frequ (Cosine Similarity: 0.4184)
# 834: Plas (Cosine Similarity: 0.4184)
# 835: holdup (Cosine Similarity: 0.4184)
# 836: cuv (Cosine Similarity: 0.4184)
# 837: exh (Cosine Similarity: 0.4183)
# 838: 1073 (Cosine Similarity: 0.4183)
# 839: pozzol (Cosine Similarity: 0.4183)
# 840: decarboxyl (Cosine Similarity: 0.4183)
# 841: methanation (Cosine Similarity: 0.4182)
# 842: biotinylated (Cosine Similarity: 0.4182)
# 843: Chitosan (Cosine Similarity: 0.4181)
# 844: Spectral (Cosine Similarity: 0.4181)
# 845: Knud (Cosine Similarity: 0.4181)
# 846: NEXAFS (Cosine Similarity: 0.4181)
# 847: Yb3 (Cosine Similarity: 0.4181)
# 848: chemotherapeutic (Cosine Similarity: 0.4180)
# 849: a4 (Cosine Similarity: 0.4180)
# 850: cadherin (Cosine Similarity: 0.4179)
# 851: observers (Cosine Similarity: 0.4179)
# 852: brightness (Cosine Similarity: 0.4179)
# 853: diastereoselectivity (Cosine Similarity: 0.4179)
# 854: heats (Cosine Similarity: 0.4178)
# 855: photographs (Cosine Similarity: 0.4178)
# 856: orogen (Cosine Similarity: 0.4178)
# 857: veloc (Cosine Similarity: 0.4178)
# 858: Ultr (Cosine Similarity: 0.4178)
# 859: frost (Cosine Similarity: 0.4178)
# 860: orogenic (Cosine Similarity: 0.4178)
# 861: EBSD (Cosine Similarity: 0.4177)
# 862: nanoshe (Cosine Similarity: 0.4177)
# 863: thermomechanical (Cosine Similarity: 0.4177)
# 864: nitriding (Cosine Similarity: 0.4177)
# 865: discon (Cosine Similarity: 0.4177)
# 866: pearlite (Cosine Similarity: 0.4176)
# 867: Thermal (Cosine Similarity: 0.4176)
# 868: disapp (Cosine Similarity: 0.4176)
# 869: resusp (Cosine Similarity: 0.4175)
# 870: C32 (Cosine Similarity: 0.4175)
# 871: CD3OD (Cosine Similarity: 0.4175)
# 872: astrocytes (Cosine Similarity: 0.4175)
# 873: н (Cosine Similarity: 0.4175)
# 874: climat (Cosine Similarity: 0.4175)
# 875: apop (Cosine Similarity: 0.4174)
# 876: æ (Cosine Similarity: 0.4174)
# 877: volcanism (Cosine Similarity: 0.4174)
# 878: carbides (Cosine Similarity: 0.4174)
# 879: hydrophobicity (Cosine Similarity: 0.4174)
# 880: erup (Cosine Similarity: 0.4173)
# 881: ṽ (Cosine Similarity: 0.4173)
# 882: Gibco (Cosine Similarity: 0.4173)
# 883: photomultiplier (Cosine Similarity: 0.4172)
# 884: PbTe (Cosine Similarity: 0.4172)
# 885: antim (Cosine Similarity: 0.4172)
# 886: fluence (Cosine Similarity: 0.4172)
# 887: brittleness (Cosine Similarity: 0.4172)
# 888: Pé (Cosine Similarity: 0.4172)
# 889: semicirc (Cosine Similarity: 0.4172)
# 890: receivers (Cosine Similarity: 0.4172)
# 891: Calculate (Cosine Similarity: 0.4172)
# 892: hemisp (Cosine Similarity: 0.4172)
# 893: nj (Cosine Similarity: 0.4171)
# 894: Approxim (Cosine Similarity: 0.4171)
# 895: protrusions (Cosine Similarity: 0.4171)
# 896: aberration (Cosine Similarity: 0.4171)
# 897: carbonized (Cosine Similarity: 0.4171)
# 898: exergy (Cosine Similarity: 0.4171)
# 899: aromaticity (Cosine Similarity: 0.4170)
# 900: ɸ (Cosine Similarity: 0.4170)
# 901: Grign (Cosine Similarity: 0.4170)
# 902: Arctic (Cosine Similarity: 0.4170)
# 903: photores (Cosine Similarity: 0.4169)
# 904: infiltr (Cosine Similarity: 0.4169)
# 905: OVA (Cosine Similarity: 0.4169)
# 906: inaccuracy (Cosine Similarity: 0.4169)
# 907: capacitances (Cosine Similarity: 0.4168)
# 908: Jasco (Cosine Similarity: 0.4168)
# 909: anthr (Cosine Similarity: 0.4168)
# 910: ωk (Cosine Similarity: 0.4167)
# 911: lysates (Cosine Similarity: 0.4167)
# 912: Excitation (Cosine Similarity: 0.4166)
# 913: opin (Cosine Similarity: 0.4166)
# 914: permeabil (Cosine Similarity: 0.4166)
# 915: Neumann (Cosine Similarity: 0.4166)
# 916: detuning (Cosine Similarity: 0.4166)
# 917: latit (Cosine Similarity: 0.4165)
# 918: JASCO (Cosine Similarity: 0.4164)
# 919: hypochlor (Cosine Similarity: 0.4164)
# 920: edible (Cosine Similarity: 0.4163)
# 921: 617 (Cosine Similarity: 0.4162)
# 922: ventil (Cosine Similarity: 0.4162)
# 923: Nicolet (Cosine Similarity: 0.4162)
# 924: 457 (Cosine Similarity: 0.4162)
# 925: integrin (Cosine Similarity: 0.4161)
# 926: hologr (Cosine Similarity: 0.4161)
# 927: Δh (Cosine Similarity: 0.4160)
# 928: mK (Cosine Similarity: 0.4160)
# 929: Activation (Cosine Similarity: 0.4160)
# 930: legis (Cosine Similarity: 0.4160)
# 931: opinions (Cosine Similarity: 0.4160)
# 932: Oxidation (Cosine Similarity: 0.4160)
# 933: circumst (Cosine Similarity: 0.4159)
# 934: trichlor (Cosine Similarity: 0.4159)
# 935: invol (Cosine Similarity: 0.4159)
# 936: spectrom (Cosine Similarity: 0.4159)
# 937: IEEE (Cosine Similarity: 0.4159)
# 938: unfav (Cosine Similarity: 0.4158)
# 939: Aluminum (Cosine Similarity: 0.4158)
# 940: amphip (Cosine Similarity: 0.4158)
# 941: Fortun (Cosine Similarity: 0.4158)
# 942: photosensi (Cosine Similarity: 0.4157)
# 943: copol (Cosine Similarity: 0.4157)
# 944: incub (Cosine Similarity: 0.4157)
# 945: sad (Cosine Similarity: 0.4156)
# 946: HAu (Cosine Similarity: 0.4156)
# 947: Immedi (Cosine Similarity: 0.4155)
# 948: ethynyl (Cosine Similarity: 0.4155)
# 949: AIE (Cosine Similarity: 0.4155)
# 950: plut (Cosine Similarity: 0.4155)
# 951: permafrost (Cosine Similarity: 0.4155)
# 952: vig (Cosine Similarity: 0.4154)
# 953: STAT3 (Cosine Similarity: 0.4154)
# 954: ② (Cosine Similarity: 0.4154)
# 955: thermost (Cosine Similarity: 0.4154)
# 956: LOI (Cosine Similarity: 0.4153)
# 957: refl (Cosine Similarity: 0.4153)
# 958: 367 (Cosine Similarity: 0.4153)
# 959: unlab (Cosine Similarity: 0.4153)
# 960: 623 (Cosine Similarity: 0.4152)
# 961: mullite (Cosine Similarity: 0.4152)
# 962: Commerc (Cosine Similarity: 0.4152)
# 963: annihil (Cosine Similarity: 0.4152)
# 964: unaff (Cosine Similarity: 0.4151)
# 965: exports (Cosine Similarity: 0.4151)
# 966: HLA (Cosine Similarity: 0.4151)
# 967: photoproduc (Cosine Similarity: 0.4151)
# 968: Κ (Cosine Similarity: 0.4151)
# 969: SiNx (Cosine Similarity: 0.4151)
# 970: Lambert (Cosine Similarity: 0.4151)
# 971: 1223 (Cosine Similarity: 0.4151)
# 972: Siem (Cosine Similarity: 0.4150)
# 973: ferroelectrics (Cosine Similarity: 0.4150)
# 974: voltamm (Cosine Similarity: 0.4150)
# 975: Publisher (Cosine Similarity: 0.4150)
# 976: sensitizers (Cosine Similarity: 0.4149)
# 977: 925 (Cosine Similarity: 0.4149)
# 978: Attribution (Cosine Similarity: 0.4149)
# 979: Eu3 (Cosine Similarity: 0.4149)
# 980: retardant (Cosine Similarity: 0.4149)
# 1162: ZnTe (Cosine Similarity: 0.4100)
# 1163: tribological (Cosine Similarity: 0.4100)
# 1164: subjective (Cosine Similarity: 0.4100)
# 1165: C29 (Cosine Similarity: 0.4099)
# 1166: Heat (Cosine Similarity: 0.4099)
# 1167: Nuss (Cosine Similarity: 0.4099)
# 1168: Č (Cosine Similarity: 0.4099)
# 1169: absorbers (Cosine Similarity: 0.4099)
# 1170: Stefan (Cosine Similarity: 0.4098)
# ...
# 22074: channel (Cosine Similarity: 0.0004)
# 22075: separate (Cosine Similarity: 0.0001)
# 22076: research (Cosine Similarity: 0.0000)
# 22077: initial (Cosine Similarity: -0.0002)
# 22078: distribution (Cosine Similarity: -0.0004)
# 22079: developed (Cosine Similarity: -0.0005)
# 22080: while (Cosine Similarity: -0.0005)
# 22081: shown (Cosine Similarity: -0.0008)
# 22082: full (Cosine Similarity: -0.0010)
# 22083: end (Cosine Similarity: -0.0010)
# 22084: has (Cosine Similarity: -0.0010)
# 22085: proposed (Cosine Similarity: -0.0011)
# 22086: storage (Cosine Similarity: -0.0012)
# 22087: PS (Cosine Similarity: -0.0013)
# 22088: run (Cosine Similarity: -0.0016)
# 22089: were (Cosine Similarity: -0.0016)
# 22090: open (Cosine Similarity: -0.0018)
# 22091: synthesis (Cosine Similarity: -0.0021)
# 22092: individual (Cosine Similarity: -0.0029)
# 22093: than (Cosine Similarity: -0.0031)
# 22094: 14 (Cosine Similarity: -0.0035)
# 22095: formed (Cosine Similarity: -0.0039)
# 22096: CH (Cosine Similarity: -0.0042)
# 22097: signal (Cosine Similarity: -0.0042)
# 22098: increase (Cosine Similarity: -0.0044)
# 22099: indicated (Cosine Similarity: -0.0048)
# 22100: mixing (Cosine Similarity: -0.0051)
# 22101: W (Cosine Similarity: -0.0054)
# 22102: ring (Cosine Similarity: -0.0054)
# 22103: Mo (Cosine Similarity: -0.0055)
# 22104: power (Cosine Similarity: -0.0056)
# 22105: provided (Cosine Similarity: -0.0058)
# 22106: treatment (Cosine Similarity: -0.0062)
# 22107: area (Cosine Similarity: -0.0065)
# 22108: 17 (Cosine Similarity: -0.0071)
# 22109: site (Cosine Similarity: -0.0074)
# 22110: relevant (Cosine Similarity: -0.0077)
# 22111: membrane (Cosine Similarity: -0.0078)
# 22112: generated (Cosine Similarity: -0.0080)
# 22113: Q (Cosine Similarity: -0.0081)
# 22114: particular (Cosine Similarity: -0.0086)
# 22115: their (Cosine Similarity: -0.0086)
# 22116: media (Cosine Similarity: -0.0087)
# 22117: ground (Cosine Similarity: -0.0091)
# 22118: modified (Cosine Similarity: -0.0092)
# 22119: forward (Cosine Similarity: -0.0097)
# 22120: equilibrium (Cosine Similarity: -0.0101)
# 22121: 60 (Cosine Similarity: -0.0103)
# 22122: concentration (Cosine Similarity: -0.0104)
# 22123: Cu (Cosine Similarity: -0.0111)
# 22124: after (Cosine Similarity: -0.0112)
# 22125: application (Cosine Similarity: -0.0112)
# 22126: studied (Cosine Similarity: -0.0115)
# 22127: p (Cosine Similarity: -0.0116)
# 22128: associated (Cosine Similarity: -0.0118)
# 22129: times (Cosine Similarity: -0.0119)
# 22130: less (Cosine Similarity: -0.0124)
# 22131: particle (Cosine Similarity: -0.0124)
# 22132: E (Cosine Similarity: -0.0126)
# 22133: CA (Cosine Similarity: -0.0126)
# 22134: addition (Cosine Similarity: -0.0130)
# 22135: glass (Cosine Similarity: -0.0132)
# 22136: net (Cosine Similarity: -0.0138)
# 22137: term (Cosine Similarity: -0.0140)
# 22138: four (Cosine Similarity: -0.0146)
# 22139: additional (Cosine Similarity: -0.0146)
# 22140: number (Cosine Similarity: -0.0148)
# 22141: values (Cosine Similarity: -0.0151)
# 22142: diffusion (Cosine Similarity: -0.0151)
# 22143: structural (Cosine Similarity: -0.0152)
# 22144: PC (Cosine Similarity: -0.0153)
# 22145: lead (Cosine Similarity: -0.0153)
# 22146: characteristic (Cosine Similarity: -0.0156)
# 22147: block (Cosine Similarity: -0.0160)
# 22148: processes (Cosine Similarity: -0.0160)
# 22149: approach (Cosine Similarity: -0.0162)
# 22150: cells (Cosine Similarity: -0.0170)
# 22151: described (Cosine Similarity: -0.0172)
# 22152: 18 (Cosine Similarity: -0.0172)
# 22153: 8 (Cosine Similarity: -0.0174)
# 22154: region (Cosine Similarity: -0.0178)
# 22155: exchange (Cosine Similarity: -0.0179)
# 22156: out (Cosine Similarity: -0.0181)
# 22157: 2D (Cosine Similarity: -0.0182)
# 22158: several (Cosine Similarity: -0.0182)
# 22159: under (Cosine Similarity: -0.0185)
# 22160: n (Cosine Similarity: -0.0189)
# 22161: zero (Cosine Similarity: -0.0190)
# 22162: neutral (Cosine Similarity: -0.0191)
# 22163: effect (Cosine Similarity: -0.0192)
# 22164: spin (Cosine Similarity: -0.0193)
# 22165: value (Cosine Similarity: -0.0194)
# 22166: significant (Cosine Similarity: -0.0195)
# 22167: g (Cosine Similarity: -0.0196)
# 22168: physical (Cosine Similarity: -0.0197)
# 22169: required (Cosine Similarity: -0.0199)
# 22170: available (Cosine Similarity: -0.0202)
# 22171: gel (Cosine Similarity: -0.0203)
# 22172: respectively (Cosine Similarity: -0.0204)
# 22173: thus (Cosine Similarity: -0.0207)
# 22174: loading (Cosine Similarity: -0.0210)
# 22175: whole (Cosine Similarity: -0.0211)
# 22176: LC (Cosine Similarity: -0.0211)
# 22177: i (Cosine Similarity: -0.0216)
# 22178: results (Cosine Similarity: -0.0218)
# 22179: G (Cosine Similarity: -0.0222)
# 22180: layer (Cosine Similarity: -0.0223)
# 22181: top (Cosine Similarity: -0.0229)
# 22182: Fe (Cosine Similarity: -0.0239)
# 22183: column (Cosine Similarity: -0.0241)
# 22184: plant (Cosine Similarity: -0.0243)
# 22185: F (Cosine Similarity: -0.0246)
# 22186: common (Cosine Similarity: -0.0250)
# 22187: contact (Cosine Similarity: -0.0251)
# 22188: fast (Cosine Similarity: -0.0251)
# 22189: MS (Cosine Similarity: -0.0252)
# 22190: average (Cosine Similarity: -0.0253)
# 22191: K (Cosine Similarity: -0.0254)
# 22192: function (Cosine Similarity: -0.0257)
# 22193: base (Cosine Similarity: -0.0258)
# 22194: solutions (Cosine Similarity: -0.0258)
# 22195: target (Cosine Similarity: -0.0259)
# 22196: pure (Cosine Similarity: -0.0260)
# 22197: limit (Cosine Similarity: -0.0262)
# 22198: still (Cosine Similarity: -0.0263)
# 22199: fixed (Cosine Similarity: -0.0268)
# 22200: carbon (Cosine Similarity: -0.0269)
# 22201: no (Cosine Similarity: -0.0269)
# 22202: scale (Cosine Similarity: -0.0275)
# 22203: J (Cosine Similarity: -0.0278)
# 22204: 11 (Cosine Similarity: -0.0284)
# 22205: reference (Cosine Similarity: -0.0285)
# 22206: limited (Cosine Similarity: -0.0285)
# 22207: various (Cosine Similarity: -0.0290)
# 22208: selected (Cosine Similarity: -0.0297)
# 22209: T (Cosine Similarity: -0.0299)
# 22210: 30 (Cosine Similarity: -0.0299)
# 22211: including (Cosine Similarity: -0.0299)
# 22212: hydrogen (Cosine Similarity: -0.0299)
# 22213: energy (Cosine Similarity: -0.0300)
# 22214: reported (Cosine Similarity: -0.0301)
# 22215: production (Cosine Similarity: -0.0304)
# 22216: typical (Cosine Similarity: -0.0307)
# 22217: constant (Cosine Similarity: -0.0308)
# 22218: change (Cosine Similarity: -0.0313)
# 22219: materials (Cosine Similarity: -0.0316)
# 22220: design (Cosine Similarity: -0.0317)
# 22221: step (Cosine Similarity: -0.0318)
# 22222: then (Cosine Similarity: -0.0322)
# 22223: short (Cosine Similarity: -0.0325)
# 22224: O (Cosine Similarity: -0.0334)
# 22225: measured (Cosine Similarity: -0.0338)
# 22226: be (Cosine Similarity: -0.0338)
# 22227: gas (Cosine Similarity: -0.0342)
# 22228: some (Cosine Similarity: -0.0342)
# 22229: maximum (Cosine Similarity: -0.0343)
# 22230: Si (Cosine Similarity: -0.0343)
# 22231: conventional (Cosine Similarity: -0.0344)
# 22232: substrate (Cosine Similarity: -0.0351)
# 22233: case (Cosine Similarity: -0.0352)
# 22234: strong (Cosine Similarity: -0.0353)
# 22235: larger (Cosine Similarity: -0.0355)
# 22236: was (Cosine Similarity: -0.0356)
# 22237: support (Cosine Similarity: -0.0375)
# 22238: structures (Cosine Similarity: -0.0376)
# 22239: 15 (Cosine Similarity: -0.0382)
# 22240: resulting (Cosine Similarity: -0.0383)
# 22241: source (Cosine Similarity: -0.0383)
# 22242: continuous (Cosine Similarity: -0.0387)
# 22243: Li (Cosine Similarity: -0.0388)
# 22244: component (Cosine Similarity: -0.0388)
# 22245: so (Cosine Similarity: -0.0392)
# 22246: range (Cosine Similarity: -0.0394)
# 22247: c (Cosine Similarity: -0.0401)
# 22248: 100 (Cosine Similarity: -0.0415)
# 22249: most (Cosine Similarity: -0.0417)
# 22250: order (Cosine Similarity: -0.0419)
# 22251: same (Cosine Similarity: -0.0419)
# 22252: samples (Cosine Similarity: -0.0420)
# 22253: chain (Cosine Similarity: -0.0423)
# 22254: D (Cosine Similarity: -0.0426)
# 22255: determined (Cosine Similarity: -0.0429)
# 22256: experimental (Cosine Similarity: -0.0430)
# 22257: following (Cosine Similarity: -0.0433)
# 22258: molecular (Cosine Similarity: -0.0435)
# 22259: R (Cosine Similarity: -0.0437)
# 22260: positive (Cosine Similarity: -0.0440)
# 22261: major (Cosine Similarity: -0.0445)
# 22262: light (Cosine Similarity: -0.0450)
# 22263: over (Cosine Similarity: -0.0453)
# 22264: 50 (Cosine Similarity: -0.0457)
# 22265: have (Cosine Similarity: -0.0462)
# 22266: V (Cosine Similarity: -0.0465)
# 22267: second (Cosine Similarity: -0.0468)
# 22268: cluster (Cosine Similarity: -0.0471)
# 22269: transition (Cosine Similarity: -0.0473)
# 22270: not (Cosine Similarity: -0.0487)
# 22271: but (Cosine Similarity: -0.0489)
# 22272: medium (Cosine Similarity: -0.0497)
# 22273: compound (Cosine Similarity: -0.0503)
# 22274: size (Cosine Similarity: -0.0505)
# 22275: 7 (Cosine Similarity: -0.0509)
# 22276: even (Cosine Similarity: -0.0513)
# 22277: complete (Cosine Similarity: -0.0518)
# 22278: conditions (Cosine Similarity: -0.0519)
# 22279: reduction (Cosine Similarity: -0.0520)
# 22280: defined (Cosine Similarity: -0.0522)
# 22281: series (Cosine Similarity: -0.0524)
# 22282: natural (Cosine Similarity: -0.0526)
# 22283: t (Cosine Similarity: -0.0528)
# 22284: use (Cosine Similarity: -0.0528)
# 22285: it (Cosine Similarity: -0.0537)
# 22286: mixed (Cosine Similarity: -0.0540)
# 22287: network (Cosine Similarity: -0.0541)
# 22288: these (Cosine Similarity: -0.0542)
# 22289: combined (Cosine Similarity: -0.0544)
# 22290: species (Cosine Similarity: -0.0552)
# 22291: lower (Cosine Similarity: -0.0554)
# 22292: mass (Cosine Similarity: -0.0556)
# 22293: parallel (Cosine Similarity: -0.0559)
# 22294: up (Cosine Similarity: -0.0559)
# 22295: simple (Cosine Similarity: -0.0572)
# 22296: active (Cosine Similarity: -0.0572)
# 22297: mean (Cosine Similarity: -0.0573)
# 22298: II (Cosine Similarity: -0.0580)
# 22299: level (Cosine Similarity: -0.0584)
# 22300: transfer (Cosine Similarity: -0.0590)
# 22301: m (Cosine Similarity: -0.0596)
# 22302: line (Cosine Similarity: -0.0611)
# 22303: possible (Cosine Similarity: -0.0611)
# 22304: specific (Cosine Similarity: -0.0612)
# 22305: h (Cosine Similarity: -0.0617)
# 22306: form (Cosine Similarity: -0.0619)
# 22307: P (Cosine Similarity: -0.0624)
# 22308: means (Cosine Similarity: -0.0626)
# 22309: three (Cosine Similarity: -0.0633)
# 22310: each (Cosine Similarity: -0.0635)
# 22311: applied (Cosine Similarity: -0.0636)
# 22312: stable (Cosine Similarity: -0.0639)
# 22313: analysis (Cosine Similarity: -0.0643)
# 22314: an (Cosine Similarity: -0.0643)
# 22315: formation (Cosine Similarity: -0.0645)
# 22316: polymer (Cosine Similarity: -0.0653)
# 22317: separation (Cosine Similarity: -0.0658)
# 22318: method (Cosine Similarity: -0.0660)
# 22319: reduced (Cosine Similarity: -0.0663)
# 22320: transport (Cosine Similarity: -0.0669)
# 22321: In (Cosine Similarity: -0.0682)
# 22322: general (Cosine Similarity: -0.0684)
# 22323: normal (Cosine Similarity: -0.0694)
# 22324: Co (Cosine Similarity: -0.0695)
# 22325: set (Cosine Similarity: -0.0703)
# 22326: 12 (Cosine Similarity: -0.0706)
# 22327: x (Cosine Similarity: -0.0711)
# 22328: long (Cosine Similarity: -0.0712)
# 22329: found (Cosine Similarity: -0.0713)
# 22330: related (Cosine Similarity: -0.0713)
# 22331: real (Cosine Similarity: -0.0715)
# 22332: similar (Cosine Similarity: -0.0722)
# 22333: matrix (Cosine Similarity: -0.0731)
# 22334: primary (Cosine Similarity: -0.0733)
# 22335: study (Cosine Similarity: -0.0735)
# 22336: work (Cosine Similarity: -0.0739)
# 22337: unit (Cosine Similarity: -0.0743)
# 22338: based (Cosine Similarity: -0.0743)
# 22339: d (Cosine Similarity: -0.0746)
# 22340: above (Cosine Similarity: -0.0748)
# 22341: L (Cosine Similarity: -0.0749)
# 22342: this (Cosine Similarity: -0.0750)
# 22343: local (Cosine Similarity: -0.0756)
# 22344: new (Cosine Similarity: -0.0762)
# 22345: solid (Cosine Similarity: -0.0763)
# 22346: group (Cosine Similarity: -0.0772)
# 22347: The (Cosine Similarity: -0.0785)
# 22348: through (Cosine Similarity: -0.0786)
# 22349: linear (Cosine Similarity: -0.0788)
# 22350: space (Cosine Similarity: -0.0792)
# 22351: peak (Cosine Similarity: -0.0794)
# 22352: higher (Cosine Similarity: -0.0798)
# 22353: further (Cosine Similarity: -0.0813)
# 22354: H (Cosine Similarity: -0.0819)
# 22355: growth (Cosine Similarity: -0.0819)
# 22356: main (Cosine Similarity: -0.0822)
# 22357: liquid (Cosine Similarity: -0.0824)
# 22358: controlled (Cosine Similarity: -0.0839)
# 22359: using (Cosine Similarity: -0.0848)
# 22360: I (Cosine Similarity: -0.0850)
# 22361: corresponding (Cosine Similarity: -0.0855)
# 22362: phase (Cosine Similarity: -0.0862)
# 22363: free (Cosine Similarity: -0.0870)
# 22364: core (Cosine Similarity: -0.0873)
# 22365: state (Cosine Similarity: -0.0879)
# 22366: such (Cosine Similarity: -0.0882)
# 22367: chemical (Cosine Similarity: -0.0882)
# 22368: bulk (Cosine Similarity: -0.0882)
# 22369: given (Cosine Similarity: -0.0883)
# 22370: metal (Cosine Similarity: -0.0889)
# 22371: other (Cosine Similarity: -0.0894)
# 22372: standard (Cosine Similarity: -0.0896)
# 22373: S (Cosine Similarity: -0.0910)
# 22374: type (Cosine Similarity: -0.0913)
# 22375: small (Cosine Similarity: -0.0915)
# 22376: material (Cosine Similarity: -0.0916)
# 22377: N (Cosine Similarity: -0.0922)
# 22378: can (Cosine Similarity: -0.0924)
# 22379: time (Cosine Similarity: -0.0935)
# 22380: systems (Cosine Similarity: -0.0941)
# 22381: like (Cosine Similarity: -0.0943)
# 22382: X (Cosine Similarity: -0.0949)
# 22383: M (Cosine Similarity: -0.0952)
# 22384: more (Cosine Similarity: -0.0959)
# 22385: current (Cosine Similarity: -0.0962)
# 22386: are (Cosine Similarity: -0.0963)
# 22387: observed (Cosine Similarity: -0.0966)
# 22388: B (Cosine Similarity: -0.0975)
# 22389: which (Cosine Similarity: -0.0977)
# 22390: potential (Cosine Similarity: -0.0986)
# 22391: total (Cosine Similarity: -0.0998)
# 22392: 20 (Cosine Similarity: -0.1009)
# 22393: sample (Cosine Similarity: -0.1010)
# 22394: field (Cosine Similarity: -0.1012)
# 22395: from (Cosine Similarity: -0.1018)
# 22396: direct (Cosine Similarity: -0.1020)
# 22397: data (Cosine Similarity: -0.1029)
# 22398: flow (Cosine Similarity: -0.1034)
# 22399: point (Cosine Similarity: -0.1047)
# 22400: reaction (Cosine Similarity: -0.1050)
# 22401: one (Cosine Similarity: -0.1055)
# 22402: also (Cosine Similarity: -0.1067)
# 22403: single (Cosine Similarity: -0.1070)
# 22404: 0 (Cosine Similarity: -0.1083)
# 22405: low (Cosine Similarity: -0.1102)
# 22406: present (Cosine Similarity: -0.1111)
# 22407: 5 (Cosine Similarity: -0.1131)
# 22408: used (Cosine Similarity: -0.1143)
# 22409: obtained (Cosine Similarity: -0.1145)
# 22410: cell (Cosine Similarity: -0.1177)
# 22411: both (Cosine Similarity: -0.1206)
# 22412: 6 (Cosine Similarity: -0.1220)
# 22413: large (Cosine Similarity: -0.1224)
# 22414: surface (Cosine Similarity: -0.1248)
# 22415: well (Cosine Similarity: -0.1257)
# 22416: at (Cosine Similarity: -0.1260)
# 22417: test (Cosine Similarity: -0.1302)
# 22418: only (Cosine Similarity: -0.1303)
# 22419: C (Cosine Similarity: -0.1320)
# 22420: all (Cosine Similarity: -0.1321)
# 22421: s (Cosine Similarity: -0.1337)
# 22422: 4 (Cosine Similarity: -0.1351)
# 22423: structure (Cosine Similarity: -0.1387)
# 22424: complex (Cosine Similarity: -0.1395)
# 22425: two (Cosine Similarity: -0.1422)
# 22426: different (Cosine Similarity: -0.1423)
# 22427: high (Cosine Similarity: -0.1460)
# 22428: that (Cosine Similarity: -0.1486)
# 22429: is (Cosine Similarity: -0.1490)
# 22430: first (Cosine Similarity: -0.1522)
# 22431: model (Cosine Similarity: -0.1525)
# 22432: with (Cosine Similarity: -0.1551)
# 22433: 3 (Cosine Similarity: -0.1564)
# 22434: A (Cosine Similarity: -0.1576)
# 22435: on (Cosine Similarity: -0.1583)
# 22436: by (Cosine Similarity: -0.1632)
# 22437: control (Cosine Similarity: -0.1639)
# 22438: water (Cosine Similarity: -0.1712)
# 22439: solution (Cosine Similarity: -0.1712)
# 22440: 10 (Cosine Similarity: -0.1763)
# 22441: for (Cosine Similarity: -0.1780)
# 22442: or (Cosine Similarity: -0.1788)
# 22443: process (Cosine Similarity: -0.1803)
# 22444: 2 (Cosine Similarity: -0.1804)
# 22445: system (Cosine Similarity: -0.1889)
# 22446: 1 (Cosine Similarity: -0.1943)
# 22447: to (Cosine Similarity: -0.2049)
# 22448: as (Cosine Similarity: -0.2053)
# 22449: a (Cosine Similarity: -0.2460)
# 22450: of (Cosine Similarity: -0.2481)
# 22451: in (Cosine Similarity: -0.2828)
# 22452: and (Cosine Similarity: -0.3071)
# 22453: the (Cosine Similarity: -0.3369)
